# %% [markdown]
# <a href="https://colab.research.google.com/github/jessicajabr/Machine-Learning-Course-Repo---Sp2021/blob/main/StyleGAN_final_270221_Trial_1_full.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x #If you are using Google Colab
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x #If you are using Google Colab`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# %pip install Google-Colab-Transfer #If you are Using Google Colab

# %%
# !apt-get install imagemagick #Image magick Instalation for Linux machines - Google Colab - Intallation for Mac and Windows: https://imagemagick.org/script/download.php
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
# ...

# %%
import colab_transfer

gd = colab_transfer.get_path_to_home_of_google_drive()
lm = colab_transfer.get_path_to_home_of_local_machine()

colab_transfer.mount_google_drive()
# Out:
# Mounted at /content/drive/

# %%
pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
#%cd /content/ #for google colab
# Clone Stylegan2-Ada repository from hithub
# !git clone https://github.com/NVlabs/stylegan2-ada.git
#%cd stylegan2-ada/ #Go to downloaded container folder
#%cd /content/ #Main folder in google colab
# Out:
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 71 (delta 2), reused 6 (delta 2), pack-reused 65
# Unpacking objects: 100% (71/71), done.

# %%
pwd
# Out:
# '/content/basefordataset/category1'

# %%
# %ls
# Out:
# 04852226-ff18-4b3e-a5de-8fe0accbd702.jpg  IMG-20190902-WA0027.jpg
# 13fab4d0-7a19-4d07-a81a-2ffaacae0d88.jpg  IMG-20190902-WA0028.jpg
# 17200816-2139-464a-9311-c452f36eec7f.jpg  IMG_20190905_234649_278.jpg
# 20190811_201821.jpg                       IMG-20190905-WA0008.jpg
# 20190811_201826.jpg                       IMG-20190905-WA0016.jpg
# 20190811_201830.jpg                       IMG-20190905-WA0017.jpg
# 20190819_195133.jpg                       IMG-20190905-WA0018.jpg
# 20190819_195140.jpg                       IMG-20190905-WA0019.jpg
# 20190819_195215.jpg                       IMG-20190905-WA0020.jpg
# 20190819_195219.jpg                       IMG-20190905-WA0021.jpg
# 20190819_195226.jpg                       IMG_20190908_150839_465.jpg
# 20190819_195941.jpg                       IMG_20190920_164825_152.jpg
# 20190819_200817.jpg                       IMG-20190920-WA0015.jpg
# 20190819_200828.jpg                       IMG-20190920-WA0018.jpg
# ...

# %%
# #Make your own dataset based on personal images
# #Create directory for Dataset Images - Deposit your images here
# %mkdir basefordataset
# %cd basefordataset
# #Create directory for Tensor flow records - # more info: https://www.tensorflow.org/tutorials/load_data/tfrecord
# %mkdir category1
# %cd category1 


#for google colab users - if you require to upload files manually
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
 print('User uploaded file "{name}" with length {length} bytes'.format(
     name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-0a736663-e36e-474f-92fc-a3ebf1550fc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a736663-e36e-474f-92fc-a3ebf1550fc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving frame625.jpg to frame625.jpg
# Saving frame626.jpg to frame626.jpg
# Saving frame627.jpg to frame627.jpg
# Saving frame628.jpg to frame628.jpg
# Saving frame605.jpg to frame605.jpg
# Saving frame606.jpg to frame606.jpg
# Saving frame607.jpg to frame607.jpg
# Saving frame608.jpg to frame608.jpg
# Saving frame609.jpg to frame609.jpg
# Saving frame610.jpg to frame610.jpg
# Saving frame611.jpg to frame611.jpg
# Saving frame612.jpg to frame612.jpg
# Saving frame613.jpg to frame613.jpg
# Saving frame614.jpg to frame614.jpg
# ...

# %%
pwd
# Out:
# '/'

# %%
# %cd /content/
# Out:
# /content

# %%
pwd
# Out:
# '/content'

# %%
#Resize all images to 256x256 - jpg
# !mogrify -resize !256x256 basefordataset/category1/*.jpg #Make sure your files are here - Change directory accordingly
# Out:
# mogrify-im6.q16: Premature end of JPEG file `basefordataset/category1/64a4b921-2783-46fc-90d1-5431338930d1.jpg' @ warning/jpeg.c/JPEGWarningHandler/352.

# %%
pwd
# Out:
# '/content'

# %%
#Use dataset_tool.py to create dataset
#use your drive path
# !python stylegan2-ada/dataset_tool.py create_from_images /content/drive/MyDrive/Dataset/ /content/basefordataset/category1/
# Out:
# Loading images from "/content/basefordataset/category1/"
# Creating dataset "/content/drive/MyDrive/Dataset/"
# stylegan2-ada/dataset_tool.py:96: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 931 images.

# %%
#Compress dataset for uploading if necessary - Google Colab
# !tar -czvf dataset.tar.gz ./drive/MyDrive/Dataset/
# Out:
# ./drive/MyDrive/Dataset/
# ./drive/MyDrive/Dataset/-r08.tfrecords
# ./drive/MyDrive/Dataset/-r07.tfrecords
# ./drive/MyDrive/Dataset/-r06.tfrecords
# ./drive/MyDrive/Dataset/-r05.tfrecords
# ./drive/MyDrive/Dataset/-r04.tfrecords
# ./drive/MyDrive/Dataset/-r03.tfrecords
# ./drive/MyDrive/Dataset/-r02.tfrecords

# %%
#Upload dataset
colab_transfer.copy_file(
   file_name="dataset.tar.gz",
   source="./",
   destination="./drive/My Drive/Datasets/",
)
# Out:
# Copying ./dataset.tar.gz to ./drive/My Drive/Datasets/dataset.tar.gz

# %%
#Copy dataset from Google Drive
colab_transfer.copy_file(
   file_name="dataset.tar.gz",
   source="./drive/My Drive/Datasets/",
   destination="./stylegan2-ada/Datasets/",
)
# Out:
# Copying ./drive/My Drive/Datasets/dataset.tar.gz to ./stylegan2-ada/Datasets/dataset.tar.gz

# %%
#Uncompress dataset
# !tar -C ./stylegan2-ada/Datasets/ -xvf ./stylegan2-ada/Datasets/dataset.tar.gz
# Out:
# ./drive/MyDrive/Dataset/
# ./drive/MyDrive/Dataset/-r08.tfrecords
# ./drive/MyDrive/Dataset/-r07.tfrecords
# ./drive/MyDrive/Dataset/-r06.tfrecords
# ./drive/MyDrive/Dataset/-r05.tfrecords
# ./drive/MyDrive/Dataset/-r04.tfrecords
# ./drive/MyDrive/Dataset/-r03.tfrecords
# ./drive/MyDrive/Dataset/-r02.tfrecords

# %%
pwd
# Out:
# '/content'

# %%
#Train Stylegan with own Dataset
#use your drive path
# !python ./stylegan2-ada/train.py \
--outdir='/content/drive/MyDrive/Output' \
--snap=6 
--data='/content/drive/MyDrive/Dataset' --mirror=true \
--metrics=none \
--cfg=auto \
--kimg=5000 \
--resume='/content/drive/MyDrive/Output/00003-Dataset-mirror-auto1-kimg5000/network-snapshot-000000.pkl' \
--freezed=10

#while True:pass
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x55973b950000 @  0x7f3e838e3001 0x7f3e80b2654f 0x7f3e80b76b58 0x7f3e80b7ab17 0x7f3e80c19203 0x5597339790e4 0x559733978de0 0x5597339ed6f5 0x5597339e7e0d 0x55973397b02c 0x5597339bbd39 0x5597339b8c84 0x5597339798e9 0x5597339edade 0x5597339e7b0e 0x5597338b9e2b 0x5597339ea1e6 0x5597339e7b0e 0x5597338b9e2b 0x5597339ea1e6 0x5597339e7e0d 0x5597338b9e2b 0x5597339ea1e6 0x55973397a69a 0x5597339e8a45 0x5597339e7b0e 0x5597339e7813 0x559733ab1592 0x559733ab190d 0x559733ab17b6 0x559733a89103
# ...

# %% [markdown]
# Step after training on machine & not data directly in drive

# %%
pwd
# Out:
# '/content'

# %%
# #Resume training from previous training run
# #use your drive path
# !python stylegan2-ada/train.py \
# --outdir='xxx' \
# --snap=6 \
# --data='xxx' \
# --mirror=true \
# --metrics=none \
# --cfg=auto \
# --kimg=5000 \
# --resume='xxx.pkl' \
# --freezed=10

#while True:pass

# %%
# #Generate Images  #Modify seed values
# !python stylegan2-ada/generate.py 
# --outdir='drive/MyDrive/Datasets/bobRoss_output' 
# --trunc=1 
# --seeds=100-150 
# --network="xxx.pkl"
